# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# convert into dataset matrix
def convertToMatrix(data, step):
 X, Y =[], []
 for i in range(len(data)-step):
  d=i+step  
  X.append(data[i:d,])
  Y.append(data[d,])
 return np.array(X), np.array(Y)

step = 4
N = 1000    
Tp = 800    

t=np.arange(0,N)
x=np.sin(0.02*t)+2*np.random.rand(N)
df = pd.DataFrame(x)
df.head()

plt.plot(df)
plt.show()

values=df.values
train,test = values[0:Tp,:], values[Tp:N,:]

# add step elements into train and test
test = np.append(test,np.repeat(test[-1,],step))
train = np.append(train,np.repeat(train[-1,],step))
 
trainX,trainY =convertToMatrix(train,step)
testX,testY =convertToMatrix(test,step)
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

model = Sequential()
model.add(SimpleRNN(units=32, input_shape=(1,step), activation="relu"))
model.add(Dense(8, activation="relu")) 
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='rmsprop')
model.summary()

model.fit(trainX,trainY, epochs=100, batch_size=16, verbose=2)
trainPredict = model.predict(trainX)
testPredict= model.predict(testX)
predicted=np.concatenate((trainPredict,testPredict),axis=0)

trainScore = model.evaluate(trainX, trainY, verbose=0)
print(trainScore)

index = df.index.values
plt.plot(index,df)
plt.plot(index,predicted)
plt.axvline(df.index[Tp], c="r")
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                1184
#
#  dense (Dense)               (None, 8)                 264
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,457
# Trainable params: 1,457
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 50/50 - 3s - loss: 0.5429 - 3s/epoch - 70ms/step
# Epoch 2/100
# 50/50 - 0s - loss: 0.4073 - 110ms/epoch - 2ms/step
# Epoch 3/100
# 50/50 - 0s - loss: 0.4009 - 116ms/epoch - 2ms/step
# Epoch 4/100
# 50/50 - 0s - loss: 0.3976 - 121ms/epoch - 2ms/step
# Epoch 5/100
# 50/50 - 0s - loss: 0.3928 - 130ms/epoch - 3ms/step
# Epoch 6/100
# 50/50 - 0s - loss: 0.3915 - 113ms/epoch - 2ms/step
# Epoch 7/100
# 50/50 - 0s - loss: 0.3898 - 112ms/epoch - 2ms/step
# Epoch 8/100
# 50/50 - 0s - loss: 0.3878 - 115ms/epoch - 2ms/step
# Epoch 9/100
# 50/50 - 0s - loss: 0.3859 - 117ms/epoch - 2ms/step
# Epoch 10/100
# 50/50 - 0s - loss: 0.3859 - 117ms/epoch - 2ms/step
# Epoch 11/100
# 50/50 - 0s - loss: 0.3846 - 112ms/epoch - 2ms/step
# Epoch 12/100
# 50/50 - 0s - loss: 0.3831 - 121ms/epoch - 2ms/step
# Epoch 13/100
# 50/50 - 0s - loss: 0.3833 - 115ms/epoch - 2ms/step
# Epoch 14/100
# 50/50 - 0s - loss: 0.3821 - 116ms/epoch - 2ms/step
# Epoch 15/100
# 50/50 - 0s - loss: 0.3820 - 114ms/epoch - 2ms/step
# Epoch 16/100
# 50/50 - 0s - loss: 0.3802 - 118ms/epoch - 2ms/step
# Epoch 17/100
# 50/50 - 0s - loss: 0.3794 - 117ms/epoch - 2ms/step
# Epoch 18/100
# 50/50 - 0s - loss: 0.3785 - 115ms/epoch - 2ms/step
# Epoch 19/100
# 50/50 - 0s - loss: 0.3795 - 118ms/epoch - 2ms/step
# Epoch 20/100
# 50/50 - 0s - loss: 0.3777 - 119ms/epoch - 2ms/step
# Epoch 21/100
# 50/50 - 0s - loss: 0.3780 - 118ms/epoch - 2ms/step
# Epoch 22/100
# 50/50 - 0s - loss: 0.3751 - 117ms/epoch - 2ms/step
# Epoch 23/100
# 50/50 - 0s - loss: 0.3734 - 115ms/epoch - 2ms/step
# Epoch 24/100
# 50/50 - 0s - loss: 0.3754 - 110ms/epoch - 2ms/step
# Epoch 25/100
# 50/50 - 0s - loss: 0.3750 - 117ms/epoch - 2ms/step
# Epoch 26/100
# 50/50 - 0s - loss: 0.3739 - 115ms/epoch - 2ms/step
# Epoch 27/100
# 50/50 - 0s - loss: 0.3748 - 119ms/epoch - 2ms/step
# Epoch 28/100
# 50/50 - 0s - loss: 0.3756 - 113ms/epoch - 2ms/step
# Epoch 29/100
# 50/50 - 0s - loss: 0.3716 - 119ms/epoch - 2ms/step
# Epoch 30/100
# 50/50 - 0s - loss: 0.3702 - 114ms/epoch - 2ms/step
# Epoch 31/100
# 50/50 - 0s - loss: 0.3730 - 115ms/epoch - 2ms/step
# Epoch 32/100
# 50/50 - 0s - loss: 0.3713 - 119ms/epoch - 2ms/step
# Epoch 33/100
# 50/50 - 0s - loss: 0.3701 - 118ms/epoch - 2ms/step
# Epoch 34/100
# 50/50 - 0s - loss: 0.3712 - 116ms/epoch - 2ms/step
# Epoch 35/100
# 50/50 - 0s - loss: 0.3705 - 122ms/epoch - 2ms/step
# Epoch 36/100
# 50/50 - 0s - loss: 0.3710 - 141ms/epoch - 3ms/step
# Epoch 37/100
# 50/50 - 0s - loss: 0.3703 - 135ms/epoch - 3ms/step
# Epoch 38/100
# 50/50 - 0s - loss: 0.3682 - 103ms/epoch - 2ms/step
# Epoch 39/100
# 50/50 - 0s - loss: 0.3678 - 120ms/epoch - 2ms/step
# Epoch 40/100
# 50/50 - 0s - loss: 0.3684 - 116ms/epoch - 2ms/step
# Epoch 41/100
# 50/50 - 0s - loss: 0.3684 - 114ms/epoch - 2ms/step
# Epoch 42/100
# 50/50 - 0s - loss: 0.3662 - 113ms/epoch - 2ms/step
# Epoch 43/100
# 50/50 - 0s - loss: 0.3665 - 119ms/epoch - 2ms/step
# Epoch 44/100
# 50/50 - 0s - loss: 0.3667 - 109ms/epoch - 2ms/step
# Epoch 45/100
# 50/50 - 0s - loss: 0.3647 - 117ms/epoch - 2ms/step
# Epoch 46/100
# 50/50 - 0s - loss: 0.3655 - 113ms/epoch - 2ms/step
# Epoch 47/100
# 50/50 - 0s - loss: 0.3666 - 119ms/epoch - 2ms/step
# Epoch 48/100
# 50/50 - 0s - loss: 0.3636 - 141ms/epoch - 3ms/step
# Epoch 49/100
# 50/50 - 0s - loss: 0.3635 - 132ms/epoch - 3ms/step
# Epoch 50/100
# 50/50 - 0s - loss: 0.3634 - 114ms/epoch - 2ms/step
# Epoch 51/100
# 50/50 - 0s - loss: 0.3637 - 132ms/epoch - 3ms/step
# Epoch 52/100
# 50/50 - 0s - loss: 0.3610 - 160ms/epoch - 3ms/step
# Epoch 53/100
# 50/50 - 0s - loss: 0.3633 - 112ms/epoch - 2ms/step
# Epoch 54/100
# 50/50 - 0s - loss: 0.3622 - 109ms/epoch - 2ms/step
# Epoch 55/100
# 50/50 - 0s - loss: 0.3617 - 112ms/epoch - 2ms/step
# Epoch 56/100
# 50/50 - 0s - loss: 0.3608 - 117ms/epoch - 2ms/step
# Epoch 57/100
# 50/50 - 0s - loss: 0.3616 - 120ms/epoch - 2ms/step
# Epoch 58/100
# 50/50 - 0s - loss: 0.3612 - 118ms/epoch - 2ms/step
# Epoch 59/100
# 50/50 - 0s - loss: 0.3597 - 109ms/epoch - 2ms/step
# Epoch 60/100
# 50/50 - 0s - loss: 0.3602 - 127ms/epoch - 3ms/step
# Epoch 61/100
# 50/50 - 0s - loss: 0.3611 - 131ms/epoch - 3ms/step
# Epoch 62/100
# 50/50 - 0s - loss: 0.3590 - 119ms/epoch - 2ms/step
# Epoch 63/100
# 50/50 - 0s - loss: 0.3584 - 105ms/epoch - 2ms/step
# Epoch 64/100
# 50/50 - 0s - loss: 0.3595 - 115ms/epoch - 2ms/step
# Epoch 65/100
# 50/50 - 0s - loss: 0.3603 - 114ms/epoch - 2ms/step
# Epoch 66/100
# 50/50 - 0s - loss: 0.3576 - 128ms/epoch - 3ms/step
# Epoch 67/100
# 50/50 - 0s - loss: 0.3586 - 117ms/epoch - 2ms/step
# Epoch 68/100
# 50/50 - 0s - loss: 0.3571 - 122ms/epoch - 2ms/step
# Epoch 69/100
# 50/50 - 0s - loss: 0.3574 - 118ms/epoch - 2ms/step
# Epoch 70/100
# 50/50 - 0s - loss: 0.3575 - 106ms/epoch - 2ms/step
# Epoch 71/100
# 50/50 - 0s - loss: 0.3588 - 116ms/epoch - 2ms/step
# Epoch 72/100
# 50/50 - 0s - loss: 0.3569 - 116ms/epoch - 2ms/step
# Epoch 73/100
# 50/50 - 0s - loss: 0.3565 - 130ms/epoch - 3ms/step
# Epoch 74/100
# 50/50 - 0s - loss: 0.3565 - 112ms/epoch - 2ms/step
# Epoch 75/100
# 50/50 - 0s - loss: 0.3572 - 110ms/epoch - 2ms/step
# Epoch 76/100
# 50/50 - 0s - loss: 0.3563 - 129ms/epoch - 3ms/step
# Epoch 77/100
# 50/50 - 0s - loss: 0.3549 - 119ms/epoch - 2ms/step
# Epoch 78/100
# 50/50 - 0s - loss: 0.3577 - 109ms/epoch - 2ms/step
# Epoch 79/100
# 50/50 - 0s - loss: 0.3565 - 112ms/epoch - 2ms/step
# Epoch 80/100
# 50/50 - 0s - loss: 0.3551 - 123ms/epoch - 2ms/step
# Epoch 81/100
# 50/50 - 0s - loss: 0.3553 - 127ms/epoch - 3ms/step
# Epoch 82/100
# 50/50 - 0s - loss: 0.3544 - 111ms/epoch - 2ms/step
# Epoch 83/100
# 50/50 - 0s - loss: 0.3555 - 134ms/epoch - 3ms/step
# Epoch 84/100
# 50/50 - 0s - loss: 0.3557 - 110ms/epoch - 2ms/step
# Epoch 85/100
# 50/50 - 0s - loss: 0.3547 - 100ms/epoch - 2ms/step
# Epoch 86/100
# 50/50 - 0s - loss: 0.3539 - 109ms/epoch - 2ms/step
# Epoch 87/100
# 50/50 - 0s - loss: 0.3542 - 135ms/epoch - 3ms/step
# Epoch 88/100
# 50/50 - 0s - loss: 0.3533 - 117ms/epoch - 2ms/step
# Epoch 89/100
# 50/50 - 0s - loss: 0.3515 - 118ms/epoch - 2ms/step
# Epoch 90/100
# 50/50 - 0s - loss: 0.3556 - 133ms/epoch - 3ms/step
# Epoch 91/100
# 50/50 - 0s - loss: 0.3533 - 109ms/epoch - 2ms/step
# Epoch 92/100
# 50/50 - 0s - loss: 0.3519 - 117ms/epoch - 2ms/step
# Epoch 93/100
# 50/50 - 0s - loss: 0.3502 - 111ms/epoch - 2ms/step
# Epoch 94/100
# 50/50 - 0s - loss: 0.3532 - 136ms/epoch - 3ms/step
# Epoch 95/100
# 50/50 - 0s - loss: 0.3512 - 113ms/epoch - 2ms/step
# Epoch 96/100
# 50/50 - 0s - loss: 0.3510 - 101ms/epoch - 2ms/step
# Epoch 97/100
# 50/50 - 0s - loss: 0.3515 - 116ms/epoch - 2ms/step
# Epoch 98/100
# 50/50 - 0s - loss: 0.3515 - 125ms/epoch - 2ms/step
# Epoch 99/100
# 50/50 - 0s - loss: 0.3498 - 116ms/epoch - 2ms/step
# Epoch 100/100
# 50/50 - 0s - loss: 0.3518 - 103ms/epoch - 2ms/step
# 0.3440704345703125
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-21ed5aadb7ab> in <module>
#      54
#      55 index = df.index.values
# ---> 56 plt.plot(index,df)
#      57 plt.plot(index,predicted)
#      58 plt.axvline(df.index[Tp], c="r")
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     387         if len(tup) == 2:
#     388             x = _check_1d(tup[0])
# --> 389             y = _check_1d(tup[-1])
#     390         else:
#     391             x, y = index_of(tup[-1])
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1316                     message='Support for multi-dimensional indexing')
#    1317
# -> 1318                 ndim = x[:, None].ndim
#    1319                 # we have definitely hit a pandas index or series object
#    1320                 # cast to a numpy array.
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\admin\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# KeyError: (slice(None, None, None), None)
